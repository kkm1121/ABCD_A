# %% [markdown]
# <a href="https://colab.research.google.com/github/kkm1121/ABCD_A/blob/20250331/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%B2%A1%ED%84%B0_%ED%95%A9%EA%B3%BC_%EB%82%B4%EC%A0%81%2C_%EC%99%B8%EC%A0%81_%EA%B3%84%EC%82%B0%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 첫 번째 벡터 입력 받기

x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))

y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))

# 두 번째 벡터 입력 받기

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))

y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))

# 벡터의 합 계산

sum_x = x1 + x2

sum_y = y1 + y2

# 벡터의 내적 계산 (dot product)
dot_product = np.dot(vector1, vector2)

# 벡터의 외적 계산 (cross product)

# 2차원 벡터의 외적은 스칼라 값으로, z축 방향의 크기를 나타냅니다

cross_product = x1 * y2 - y1 * x2  # 2D 외적은 스칼라 값

# 결과 출력

print("\n벡터 1:", x1, "i +", y1, "j")

print("벡터 2:", x2, "i +", y2, "j")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j")

print("벡터의 내적:", dot_product)

print("벡터의 외적:", cross_product)
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 3
# 첫 번째 벡터의 y 성분을 입력하세요: 6
# 두 번째 벡터의 x 성분을 입력하세요: 6
# 두 번째 벡터의 y 성분을 입력하세요: 3
#
# 벡터 1: 3.0 i + 6.0 j
# 벡터 2: 6.0 i + 3.0 j
#
# 벡터의 합: 9.0 i + 9.0 j
# 벡터의 내적: 90.0
# 벡터의 외적: -27.0

# %%
# 첫 번째 벡터 입력 받기
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))
z1 = float(input("첫 번째 벡터의 z 성분을 입력하세요: "))

# 두 번째 벡터 입력 받기
x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))
z2 = float(input("두 번째 벡터의 z 성분을 입력하세요: "))

# 벡터 정의
vector1 = np.array([x1, y1, z1])
vector2 = np.array([x2, y2, z2])

# 벡터의 합 계산
vector_sum = vector1 + vector2

# 벡터의 내적 계산 (dot product)
dot_product = np.dot(vector1, vector2)

# 벡터의 외적 계산 (cross product)
cross_product = np.cross(vector1, vector2)

# 결과 출력
print("\n벡터 1:", vector1[0], "i +", vector1[1], "j +", vector1[2], "k")
print("벡터 2:", vector2[0], "i +", vector2[1], "j +", vector2[2], "k")
print("\n벡터의 합:", vector_sum[0], "i +", vector_sum[1], "j +", vector_sum[2], "k")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product[0], "i +", cross_product[1], "j +", cross_product[2], "k")
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 3
# 첫 번째 벡터의 y 성분을 입력하세요: 6
# 첫 번째 벡터의 z 성분을 입력하세요: 9
# 두 번째 벡터의 x 성분을 입력하세요: 9
# 두 번째 벡터의 y 성분을 입력하세요: 6
# 두 번째 벡터의 z 성분을 입력하세요: 3
#
# 벡터 1: 3.0 i + 6.0 j + 9.0 k
# 벡터 2: 9.0 i + 6.0 j + 3.0 k
#
# 벡터의 합: 12.0 i + 12.0 j + 12.0 k
# 벡터의 내적: 90.0
# 벡터의 외적: -36.0 i + 72.0 j + -36.0 k
